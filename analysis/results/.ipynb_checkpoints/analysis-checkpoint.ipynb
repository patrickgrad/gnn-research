# %%
import pandas as pd
from glob import glob

# %%
def compute_bytes(d):
    tot = 2* d['Floating Point Operations(Half Precision)'] + \
          4* d['Floating Point Operations(Single Precision)'] + \
          8* d['Floating Point Operations(Double Precision)']
    tot = tot * d['Invocations']
    return tot

def req_nonlocal_bytes(d):
    tot = (d['Requested Global Load Throughput(bytes/sec)'] + d['Shared Memory Load Throughput(bytes/sec)']) * (d['Avg. Duration(ns)'] * d['Invocations'])
    tot = tot *  1.0e-9 # nanoseconds to seconds
    return tot

def trans_nonlocal_bytes(d):
    tot = (d['Global Load Throughput(bytes/sec)'] + d['Shared Memory Load Throughput(bytes/sec)']) * d['Avg. Duration(ns)'] * d['Invocations']
    tot = tot* 1.0e-9 # nanoseconds to seconds
    return tot

def unified_hits(d):
    return d['Unified Cache Transactions'] * (d['Unified Cache Hit Rate(%)'] / 100.0) * d['Invocations']

def unified_misses(d):
    return d['Unified Cache Transactions'] * (1.0 - (d['Unified Cache Hit Rate(%)'] / 100.0)) * d['Invocations']

# %%
data = {}
for i in glob('*/metrics.csv'):
    print(i)
    d = pd.read_csv(i, index_col='Name', skipinitialspace=True)
    
    #print(d['name'] == 'memset (0)')
    if 'memset (0)' in d.index :
        d.drop(['memset (0)'], inplace=True)
    data[i] = d
# Out:
# mpnnv1_forward_10n_1b/metrics.csv
# gcn_inference/metrics.csv
# gat_sparse_backward_10n_1b/metrics.csv
# gat_dense_forward_10n_1b/metrics.csv
# gat_sparse_forward_10n_1b/metrics.csv
# mpnnv2_backward_10n_1b/metrics.csv
# deeplab_coco_2n_2b_forward/metrics.csv
# mpnnv2_forward_n10_1b/metrics.csv
# mpnnv1_backward_10n_1b/metrics.csv
# multiscale_backward_10n_10b/metrics.csv
# deeplab_coco_2n_2b_backward/metrics.csv
# multiscale_forward_10n_10b/metrics.csv

# %%
def gen_stats(d):
    req_bytes = req_nonlocal_bytes(d)
    trans_bytes = trans_nonlocal_bytes(d)
    flops = compute_bytes(d)
    u_hits = unified_hits(d)
    u_misses = unified_misses(d)

    stats = {}
    stats['c_to_m'] = (flops.sum())/(req_bytes.sum())
    stats['load_efficiency'] = (req_bytes.sum())/(trans_bytes.sum())
    stats['unified_hit_rate'] = (u_hits.sum())/(u_hits.sum() + u_misses.sum())
    
    return stats

for n, d in data.items():
    s = gen_stats(d)
    print(n)
    print(s)
# Out:
# mpnnv1_forward_10n_1b/metrics.csv
# {'c_to_m': 20.69521704998328, 'load_efficiency': 0.9662851353426587, 'unified_hit_rate': 0.4460015009992953}
# gcn_inference/metrics.csv
# {'c_to_m': 0.3000613883392695, 'load_efficiency': 0.8978298032897908, 'unified_hit_rate': 0.4310846417801808}
# gat_sparse_backward_10n_1b/metrics.csv
# {'c_to_m': 2.78283781322423, 'load_efficiency': 0.885026922362856, 'unified_hit_rate': 0.42876309344224484}
# gat_dense_forward_10n_1b/metrics.csv
# {'c_to_m': 25.818191294570255, 'load_efficiency': 0.9736218256918661, 'unified_hit_rate': 0.5469508236491517}
# gat_sparse_forward_10n_1b/metrics.csv
# {'c_to_m': 1.8449044424548764, 'load_efficiency': 0.7220746112608303, 'unified_hit_rate': 0.28703154445554907}
# mpnnv2_backward_10n_1b/metrics.csv
# {'c_to_m': 7.65779936786059, 'load_efficiency': 0.9381453435015384, 'unified_hit_rate': 0.28348211659273637}
# deeplab_coco_2n_2b_forward/metrics.csv
# {'c_to_m': 10.37110501015489, 'load_efficiency': 0.8598571423661392, 'unified_hit_rate': 0.5652247092778045}
# mpnnv2_forward_n10_1b/metrics.csv
# {'c_to_m': 9.72333435204418, 'load_efficiency': 0.9672886701834208, 'unified_hit_rate': 0.22438231641271217}
# mpnnv1_backward_10n_1b/metrics.csv
# {'c_to_m': 8.813103818669683, 'load_efficiency': 0.591634194671817, 'unified_hit_rate': 0.6641492102106384}
# multiscale_backward_10n_10b/metrics.csv
# {'c_to_m': 8.034421204134349, 'load_efficiency': 0.45062175507957575, 'unified_hit_rate': 0.5354392439152533}
# deeplab_coco_2n_2b_backward/metrics.csv
# {'c_to_m': 9.884879831348771, 'load_efficiency': 0.8006296689852103, 'unified_hit_rate': 0.5687140910709633}
# multiscale_forward_10n_10b/metrics.csv
# {'c_to_m': 8.423483394849026, 'load_efficiency': 2.504536694633156, 'unified_hit_rate': 0.5035287092215104}

# %%
from IPython.display import display

for n, d in data.items():
    print("===========")
    print(n)
    print("-----------")
    print("Effiencicy")
    print(req_nonlocal_bytes(d)/trans_nonlocal_bytes(d))
    
    print("-----------")
    print("L1 Hit")
    print(unified_hits(d)/unified_misses(d))
    
    print("-----------")
    print("Comp:Mem")
    print(compute_bytes(d)/req_nonlocal_bytes(d))
# Out:
# ===========
# mpnnv1_forward_10n_1b/metrics.csv
# -----------
# Effiencicy
# Name
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=1, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=1>, float, float)                                                                                             0.998828
# void kernelPointwiseApply2<TensorSigmoidOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorSigmoidOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                    0.986864
# void kernelPointwiseApply2<CopyOp<float, unsigned char>, float, unsigned char, unsigned int, int=1, int=1>(OffsetInfo<unsigned char, float, unsigned char>, OffsetInfo<CopyOp<float, unsigned char>, float, unsigned int>, float, float)                                                                                                0.997073
# void kernelPointwiseApply2<TensorGTValueOp<float, unsigned char>, unsigned char, float, unsigned int, int=1, int=2>(OffsetInfo<unsigned char, unsigned char, float>, OffsetInfo<TensorGTValueOp<float, unsigned char>, unsigned char, unsigned int>, unsigned char, float)                                                              0.176455
# void kernelReduceContigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                                    0.983129
# void CatArrayBatchedCopy<float, unsigned int, int=2>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                          0.334039
# void kernelReduceNoncontigDim_shared<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float, float volatile *, int*)    0.928346
# void CatArrayBatchedCopy<float, unsigned int, int=3>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                          0.585932
# void kernelReduceNoncontigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=2>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                   0.823916
# void kernelPointwiseApply2<TensorMaxValueOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorMaxValueOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                  1.000000
# void GRU_elementWise_fp<float, float, float>(int, int, int, int, float const *, float const *, float const *, float*, float const *, float*, float*, bool, bool, int)                                                                                                                                                                   0.779363
# sgemm_32x32x32_NT_vec                                                                                                                                                                                                                                                                                                                   0.999988
# sgemm_32x32x32_NT                                                                                                                                                                                                                                                                                                                       0.821554
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=2, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=2>, float, float)                                                                                             0.828798
# maxwell_sgemm_64x64_tn                                                                                                                                                                                                                                                                                                                  0.898445
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=2>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                        0.830431
# maxwell_sgemm_128x64_tn                                                                                                                                                                                                                                                                                                                 0.950424
# sgemm_128x128x8_NT_vec                                                                                                                                                                                                                                                                                                                  0.990087
# dtype: float64
# -----------
# L1 Hit
# Name
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=1, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=1>, float, float)                                                                                             0.977027
# void kernelPointwiseApply2<TensorSigmoidOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorSigmoidOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                    0.973671
# void kernelPointwiseApply2<CopyOp<float, unsigned char>, float, unsigned char, unsigned int, int=1, int=1>(OffsetInfo<unsigned char, float, unsigned char>, OffsetInfo<CopyOp<float, unsigned char>, float, unsigned int>, float, float)                                                                                                1.364402
# void kernelPointwiseApply2<TensorGTValueOp<float, unsigned char>, unsigned char, float, unsigned int, int=1, int=2>(OffsetInfo<unsigned char, unsigned char, float>, OffsetInfo<TensorGTValueOp<float, unsigned char>, unsigned char, unsigned int>, unsigned char, float)                                                              2.831711
# void kernelReduceContigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                                    0.755156
# void CatArrayBatchedCopy<float, unsigned int, int=2>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                          1.950636
# void kernelReduceNoncontigDim_shared<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float, float volatile *, int*)    0.499993
# void CatArrayBatchedCopy<float, unsigned int, int=3>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                          1.390686
# void kernelReduceNoncontigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=2>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                   0.949432
# void kernelPointwiseApply2<TensorMaxValueOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorMaxValueOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                  1.000000
# void GRU_elementWise_fp<float, float, float>(int, int, int, int, float const *, float const *, float const *, float*, float const *, float*, float*, bool, bool, int)                                                                                                                                                                   1.652520
# sgemm_32x32x32_NT_vec                                                                                                                                                                                                                                                                                                                   0.119307
# sgemm_32x32x32_NT                                                                                                                                                                                                                                                                                                                       2.964950
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=2, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=2>, float, float)                                                                                             1.218180
# maxwell_sgemm_64x64_tn                                                                                                                                                                                                                                                                                                                  1.514711
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=2>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                        2.111872
# maxwell_sgemm_128x64_tn                                                                                                                                                                                                                                                                                                                 1.453386
# sgemm_128x128x8_NT_vec                                                                                                                                                                                                                                                                                                                  0.540666
# dtype: float64
# -----------
# Comp:Mem
# Name
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=1, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=1>, float, float)                                                                                              0.643908
# void kernelPointwiseApply2<TensorSigmoidOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorSigmoidOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                    24.265114
# void kernelPointwiseApply2<CopyOp<float, unsigned char>, float, unsigned char, unsigned int, int=1, int=1>(OffsetInfo<unsigned char, float, unsigned char>, OffsetInfo<CopyOp<float, unsigned char>, float, unsigned int>, float, float)                                                                                                 0.000000
# void kernelPointwiseApply2<TensorGTValueOp<float, unsigned char>, unsigned char, float, unsigned int, int=1, int=2>(OffsetInfo<unsigned char, unsigned char, float>, OffsetInfo<TensorGTValueOp<float, unsigned char>, unsigned char, unsigned int>, unsigned char, float)                                                               0.000000
# void kernelReduceContigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                                     0.158822
# void CatArrayBatchedCopy<float, unsigned int, int=2>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                           0.000000
# void kernelReduceNoncontigDim_shared<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=1>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float, float volatile *, int*)     0.860824
# void CatArrayBatchedCopy<float, unsigned int, int=3>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                           0.000000
# void kernelReduceNoncontigDim<float, unsigned int, float, thrust::identity<float>, ReduceAdd<float>, thrust::identity<float>, int=1, int=2>(TensorInfo<float, unsigned int>, TensorInfo<float, unsigned int>, unsigned int, unsigned int, unsigned int, float, float, thrust::identity<float>, float)                                    3.941463
# void kernelPointwiseApply2<TensorMaxValueOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorMaxValueOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                   0.000000
# void GRU_elementWise_fp<float, float, float>(int, int, int, int, float const *, float const *, float const *, float*, float const *, float*, float*, bool, bool, int)                                                                                                                                                                    4.484512
# sgemm_32x32x32_NT_vec                                                                                                                                                                                                                                                                                                                   13.639471
# sgemm_32x32x32_NT                                                                                                                                                                                                                                                                                                                        7.914938
# void kernelPointwiseApply3<TensorMulOp<float>, float, float, float, unsigned int, int=1, int=2, int=1>(OffsetInfo<TensorMulOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, OffsetInfo<float, float, int=2>, float, float)                                                                                              2.455674
# maxwell_sgemm_64x64_tn                                                                                                                                                                                                                                                                                                                  12.523539
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=2>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                         0.000000
# maxwell_sgemm_128x64_tn                                                                                                                                                                                                                                                                                                                 22.677480
# sgemm_128x128x8_NT_vec                                                                                                                                                                                                                                                                                                                  21.049665
# dtype: float64
# ===========
# gcn_inference/metrics.csv
# -----------
# Effiencicy
# Name
# void kernelTransformReduceInnermostDimIndex<long, long, MaxValuePair<long, long>>(long*, long*, long*, unsigned int, unsigned int, thrust::pair<long, long>, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.888785
# void kernelTransformReduceInnermostDimIndex<float, long, MaxValuePair<float, long>>(float*, long*, float*, unsigned int, unsigned int, thrust::pair<float, long>, float)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.952817
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__merge_sort::BlockSortAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, long, ThrustLTOp<long>, thrust::detail::integral_constant<bool, bool=1>, thrust::detail::integral_constant<bool, bool=0>>, bool, thrust::device_ptr<long>, thrust::device_ptr<long>, long, long*, long*, ThrustLTOp<long>>(thrust::device_ptr<long>, thrust::device_ptr<long>, long, long, ThrustLTOp<long>, bool, bool=1)                                                                                                                                                                                                                                                                                                  0.999914
# sgemm_32x32x32_NN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.577403
# void convert_CooToCsr_kernel<int=0>(int const *, int, int, int*)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.931818
# void kernelTransformReduceInnermostDimIndex<long, long, MinValuePair<long, long>>(long*, long*, long*, unsigned int, unsigned int, thrust::pair<long, long>, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.888681
# void csrMmt_hyb_core<float, int=4, int=4>(float, float, float const *, float const *, float const *, int const *, int const *, float const *, float*, int, int, int, int, int, int, bool)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.793103
# void csrMmt_hyb_core<float, int=3, int=5>(float, float, float const *, float const *, float const *, int const *, int const *, float const *, float*, int, int, int, int, int, int, bool)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.690106
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_16gpu_unary_kernelIZNS0_17gpu_binary_kernelIZNS0_15div_kernel_implIlEEvRNS_14TensorIteratorEEUlllE_EEvS6_RKT_EUllE0_EEvS6_SA_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1.000000
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__unique_by_key::InitAgent<thrust::cuda_cub::cub::ScanTileState<int, bool=1>, int*, int>, thrust::cuda_cub::cub::ScanTileState<int, bool=1>, unsigned long, int*>(bool=1, thrust::cuda_cub::cub::ScanTileState<int, bool=1>, int*)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# _ZN2at6native18elementwise_kernelILi128ELi4EZNS0_17gpu_binary_kernelIZNS0_15mul_kernel_implIlEEvRNS_14TensorIteratorEEUlllE_EEvS5_RKT_EUliE0_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.917012
# _ZN2at6native18elementwise_kernelILi128ELi4EZNS0_17gpu_binary_kernelIZNS0_15add_kernel_implIfEEvRNS_14TensorIteratorEN3c106ScalarEEUlffE_EEvS5_RKT_EUliE0_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.870760
# void csrMmt_hyb_core<float, int=5, int=3>(float, float, float const *, float const *, float const *, int const *, int const *, float const *, float*, int, int, int, int, int, int, bool)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.694888
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__merge_sort::MergeAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, long, ThrustLTOp<long>, thrust::detail::integral_constant<bool, bool=1>>, bool, thrust::device_ptr<long>, thrust::device_ptr<long>, long, long*, long*, ThrustLTOp<long>, long*, long>(thrust::device_ptr<long>, thrust::device_ptr<long>, long, long, ThrustLTOp<long>, bool, bool=1, thrust::detail::integral_constant<bool, bool=1>, thrust::cuda_cub::__merge_sort::MergeAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, long, ThrustLTOp<long>, thrust::detail::integral_constant<bool, bool=1>>)                                                                                                                0.989242
# _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIdZNS0_15sum_kernel_implIddEEvRNS_14TensorIteratorEEUlddE_EEEEvT0_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1.000000
# _ZN2at4cuda74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a321kernelPointwiseApply2IZN74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a36CopyOpIffE5applyERNS_6TensorERKS6_EUlRfRKfE_ffjLi1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSF_IT1_SH_EESH_T_                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.125128
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_17gpu_binary_kernelIZNS0_21threshold_kernel_implIfEEvRNS_14TensorIteratorET_S6_EUlffE_EEvS5_RKS6_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0.778302
# _ZN2at4cuda74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a321kernelPointwiseApply2IZN74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a36CopyOpIdhE5applyERNS_6TensorERKS6_EUlRdRKhE_dhjLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSF_IT1_SH_EESH_T_                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.250569
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__merge_sort::PartitionAgent<thrust::device_ptr<long>, long, ThrustLTOp<long>>, bool, thrust::device_ptr<long>, long*, long, unsigned long, long*, ThrustLTOp<long>, long, int>(thrust::device_ptr<long>, long, long, ThrustLTOp<long>, thrust::cuda_cub::__merge_sort::PartitionAgent<thrust::device_ptr<long>, long, ThrustLTOp<long>>, bool, thrust::device_ptr<long>, long*, long)                                                                                                                                                                                                                                                                                                                       0.249997
# _ZN2at6native18elementwise_kernelILi128ELi4EZNS0_16gpu_unary_kernelIZNS0_17div_constant_implIdEEvRNS_14TensorIteratorET_EUldE_EEvS5_RKS6_EUliE0_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.230769
# void at::native::apply::coalesceValuesKernel<float, float>(long*, at::native::apply::coalesceValuesKernel<float, float>, float*, float, long, long, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.125383
# _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIlZNS0_15sum_kernel_implIllEEvRNS_14TensorIteratorEEUlllE_EEEEvT0_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.938462
# void kernelPointwiseApply3<TensorEQOp<long, unsigned char>, unsigned char, long, long, unsigned int, int=1, int=1, int=1>(OffsetInfo<unsigned char, long, long>, OffsetInfo<TensorEQOp<long, unsigned char>, long, unsigned int>, OffsetInfo<unsigned char, long, int=1>, long, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1.000000
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_17gpu_binary_kernelIZNS0_15add_kernel_implIlEEvRNS_14TensorIteratorEN3c106ScalarEEUlllE_EEvS5_RKT_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.969900
# _ZN2at6native18elementwise_kernelILi128ELi4EZNS0_16gpu_index_kernelIZNS0_17index_kernel_implINS0_10OpaqueTypeILi4EEEEEvRNS_14TensorIteratorEN3c108ArrayRefIlEESA_EUlPcSB_lE_EEvS7_SA_SA_RKT_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.719457
# _ZN2at4cuda74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a321kernelPointwiseApply2IZN74_GLOBAL__N__50_tmpxft_0000d15e_00000000_9_Copy_compute_70_cpp1_ii_dd3fb9a36CopyOpIilE5applyERNS_6TensorERKS6_EUlRiRKlE_iljLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSF_IT1_SH_EESH_T_                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.334118
# void cunn_ClassNLLCriterion_updateOutput_kernel<float, float>(float*, float*, float*, long*, float*, int, int, int, int, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.335214
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__parallel_for::ParallelForAgent<thrust::cuda_cub::__transform::unary_transform_f<thrust::counting_iterator<long, thrust::use_default, thrust::use_default, thrust::use_default>, thrust::device_ptr<long>, thrust::cuda_cub::__transform::no_stencil_tag, thrust::identity<long>, thrust::cuda_cub::__transform::always_true_predicate>, long>, thrust::cuda_cub::__transform::unary_transform_f<thrust::counting_iterator<long, thrust::use_default, thrust::use_default, thrust::use_default>, thrust::device_ptr<long>, thrust::cuda_cub::__transform::no_stencil_tag, thrust::identity<long>, thrust::cuda_cub::__transform::always_true_predicate>, long>(thrust::use_default, thrust::use_default)         NaN
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__unique_by_key::UniqueByKeyAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::equal_to<long>, int, int*>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::equal_to<long>, int*, int, thrust::cuda_cub::cub::ScanTileState<int, bool=1>, unsigned long>(thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, long, thrust::equal_to<long>, int, int*, thrust::cuda_cub::__unique_by_key::UniqueByKeyAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, thrust::device_ptr<long>, thrust                         0.952128
# _ZN2at6native18elementwise_kernelILi128ELi4EZNS0_16gpu_index_kernelIZNS0_17index_kernel_implINS0_10OpaqueTypeILi8EEEEEvRNS_14TensorIteratorEN3c108ArrayRefIlEESA_EUlPcSB_lE_EEvS7_SA_SA_RKT_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.615160
# dtype: float64
# -----------
# L1 Hit
# Name
# void kernelTransformReduceInnermostDimIndex<long, long, MaxValuePair<long, long>>(long*, long*, long*, unsigned int, unsigned int, thrust::pair<long, long>, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.333333
# void kernelTransformReduceInnermostDimIndex<float, long, MaxValuePair<float, long>>(float*, long*, float*, unsigned int, unsigned int, thrust::pair<float, long>, float)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.700015
# void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__merge_sort::BlockSortAgent<thrust::device_ptr<long>, thrust::device_ptr<long>, long, ThrustLTOp<long>, thrust::detail::integral_constant<bool, bool=1>, thrust::detail::integral_constant<bool, bool=0>>, bool, thrust::device_ptr<long>, thrust::device_ptr<long>, long, long*, long*, ThrustLTOp<long>>(thrust::device_ptr<long>, thrust::device_ptr<long>, long, long, ThrustLTOp<long>, bool, bool=1)                                                                                                                                                                                                                                                                                                  0.011675
# sgemm_32x32x32_NN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3.231909
# void convert_CooToCsr_kernel<int=0>(int const *, int, int, int*)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.901213
# void kernelTransformReduceInnermostDimIndex<long, long, MinValuePair<long, long>>(long*, long*, long*, unsigned int, unsigned int, thrust::pair<long, long>, long)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.333333
# void csrMmt_hyb_core<float, int=4, int=4>(float, float, float const *, float const *, float const *, int const *, int const *, float const *, float*, int, int, int, int, int, int, bool)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.951220
# void csrMmt_hyb_core<float, int=3, int=5>(float, float, float const *, float const *, float const *, int const *, int const *, float const *, float*, int, int, int, int, int, int, bool)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.633907
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_16gpu_unary_kernelIZNS0_17gpu_binary_kernelIZNS0_15div_kernel_implIlEEvRNS_14TensorIteratorEEUlllE_EEvS6_RKT_EUllE0_EEvS6_SA_EUliE_EEviT1_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.000000
# ...
# void gemv2N_kernel_val<float, float, float, int=128, int=8, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                           0.821527
# sgemm_32x32x32_NN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  -1.845209
# void gemv2N_kernel_val<float, float, float, int=128, int=4, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                           0.871721
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                                                                                                                                                                                    0.199995
# dtype: float64
# -----------
# L1 Hit
# Name
# void kernelPointwiseApply2<TensorMaxValueOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorMaxValueOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                                                                                                                                                                              0.986255
# void kernelPointwiseApply1<TensorAddConstantOp<long>, long, unsigned int, int=1>(OffsetInfo<TensorAddConstantOp<long>, long, unsigned int>, long, long)                                                                                                                                                                                                                                                                                                                                             0.000000
# cudnn::maxwell::gemm::computeOffsetsKernel(cudnn::maxwell::gemm::ComputeOffsetsParams)                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# void add_tensor_kernel_v3<int=2, float, float, int=128, int=1, int=1, int=4, int=2>(cudnnTensorStruct, float*, cudnnTensorStruct, float const *, float, float)                                                                                                                                                                                                                                                                                                                                      1.372367
# void gemv2N_kernel_val<float, float, float, int=128, int=32, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                          0.215318
# void CatArrayBatchedCopy<float, unsigned int, int=4>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                                                                                                                                                                                      2.303601
# void cudnn::detail::bn_fw_tr_1C11_singleread<float, int=512, bool=1, int=1, int=2, int=0>(cudnnTensorStruct, float const *, cudnn::detail::bn_fw_tr_1C11_singleread<float, int=512, bool=1, int=1, int=2, int=0>, cudnnTensorStruct*, float const *, float const , float, float, float*, float const *, float const *, float const *, float, float, cudnn::reduced_divisor, int, float*, cudnn::detail::bnFwPersistentState*, int, float, float, float, int, float, float, cudnnStatus_t*, bool)    3.490547
# void CatArrayBatchedCopy<float, unsigned int, int=3>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                                                                                                                                                                                      2.159358
# sgemm_32x32x32_NN_vec                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.333618
# maxwell_scudnn_128x32_relu_interior_nn                                                                                                                                                                                                                                                                                                                                                                                                                                                              2.367570
# void gemv2N_kernel_val<float, float, float, int=128, int=8, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                           0.632466
# sgemm_32x32x32_NN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2.940576
# void gemv2N_kernel_val<float, float, float, int=128, int=4, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                           0.827719
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                                                                                                                                                                                    0.261114
# dtype: float64
# -----------
# Comp:Mem
# Name
# void kernelPointwiseApply2<TensorMaxValueOp<float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<TensorMaxValueOp<float>, float, unsigned int>, OffsetInfo<float, float, int=1>, float, float)                                                                                                                                                                                                                                                                                               0.000000
# void kernelPointwiseApply1<TensorAddConstantOp<long>, long, unsigned int, int=1>(OffsetInfo<TensorAddConstantOp<long>, long, unsigned int>, long, long)                                                                                                                                                                                                                                                                                                                                              0.000000
# cudnn::maxwell::gemm::computeOffsetsKernel(cudnn::maxwell::gemm::ComputeOffsetsParams)                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# void add_tensor_kernel_v3<int=2, float, float, int=128, int=1, int=1, int=4, int=2>(cudnnTensorStruct, float*, cudnnTensorStruct, float const *, float, float)                                                                                                                                                                                                                                                                                                                                       4.099130
# void gemv2N_kernel_val<float, float, float, int=128, int=32, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                           0.541832
# void CatArrayBatchedCopy<float, unsigned int, int=4>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                                                                                                                                                                                       0.000000
# void cudnn::detail::bn_fw_tr_1C11_singleread<float, int=512, bool=1, int=1, int=2, int=0>(cudnnTensorStruct, float const *, cudnn::detail::bn_fw_tr_1C11_singleread<float, int=512, bool=1, int=1, int=2, int=0>, cudnnTensorStruct*, float const *, float const , float, float, float*, float const *, float const *, float const *, float, float, cudnn::reduced_divisor, int, float*, cudnn::detail::bnFwPersistentState*, int, float, float, float, int, float, float, cudnnStatus_t*, bool)     5.563899
# void CatArrayBatchedCopy<float, unsigned int, int=3>(float*, CatArrInputTensor<float, unsigned int>*, OutputTensorSizeStride<unsigned int, unsigned int=4>, int, unsigned int)                                                                                                                                                                                                                                                                                                                       0.000000
# sgemm_32x32x32_NN_vec                                                                                                                                                                                                                                                                                                                                                                                                                                                                               11.959111
# maxwell_scudnn_128x32_relu_interior_nn                                                                                                                                                                                                                                                                                                                                                                                                                                                               9.953184
# void gemv2N_kernel_val<float, float, float, int=128, int=8, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                            1.635669
# sgemm_32x32x32_NN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    9.603581
# void gemv2N_kernel_val<float, float, float, int=128, int=4, int=4, int=4, int=1>(float, float, cublasGemv2Params_v2<float, float, float>)                                                                                                                                                                                                                                                                                                                                                            1.415309
# void kernelPointwiseApply2<CopyOp<float, float>, float, float, unsigned int, int=1, int=1>(OffsetInfo<float, float, float>, OffsetInfo<CopyOp<float, float>, float, unsigned int>, float, float)                                                                                                                                                                                                                                                                                                     0.000000
# dtype: float64

# %%
# %matplotlib notebook
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
